# %% [markdown]
# <a href="https://colab.research.google.com/github/nirvanagarcia/Cosillas-de-algoritmos/blob/main/Pruebita.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile funcion.cpp
# #include <iostream>
# using namespace std;

# %%
# !g++ recursividad.cpp && ./a.out
